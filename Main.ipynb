# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content

# %%
# !rm -rf MaskArchitectureAnomaly_CourseProject

# Clone repository project
# !git clone https://github.com/vittoria1108/MaskArchitectureAnomaly_CourseProject.git
# Out:
# Cloning into 'MaskArchitectureAnomaly_CourseProject'...
# remote: Enumerating objects: 919, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 919 (delta 13), reused 17 (delta 7), pack-reused 889 (from 1)
# Receiving objects: 100% (919/919), 34.47 MiB | 15.64 MiB/s, done.
# Resolving deltas: 100% (559/559), done.

# %%
# %cd MaskArchitectureAnomaly_CourseProject/

# Installing requirements
# !pip install ood-metrics wandb
# !pip install -r eomt/requirements.txt
# Out:
# /content/MaskArchitectureAnomaly_CourseProject
# ...
#   Using cached gitignore_parser-0.1.12.tar.gz (5.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 112.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 104.1 MB/s eta 0:00:00
# ...

# %%
###### ERFNET ######
# %cd /content/MaskArchitectureAnomaly_CourseProject/

# !PYTHONPATH=".:./eomt" python eval/evalAnomaly.py \
  --model_type erfnet \
  --loadDir "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/trained_models/" \
  --loadWeights "erfnet_pretrained.pth" \
  --input "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/datasets/Validation_Dataset/RoadAnomaly21/images/*.png"
# Out:
# /content/MaskArchitectureAnomaly_CourseProject
# Device: cuda
#
# START OF EVALUATION WITH MODEL: ERFNET
#
#
# Anomaly dataset evaluation in progress...
# Found 10 anomaly images.
#
# [*] Debug image saved: debug_pred_RoadAnomaly21.png
#
# ...
# Final metrics calculation
# ...
# [MSP] AUPRC: 29.10% | FPR95: 62.55%
# [MAX LOGIT] AUPRC: 38.32% | FPR95: 59.34%
# [ENTROPIA] AUPRC: 30.97% | FPR95: 62.66%
#
# Complete report saved in 'results.txt'

# %%
# Evaluation of mIoU

import os
os.environ["WANDB_MODE"] = "disabled"

# %cd /content/MaskArchitectureAnomaly_CourseProject/eomt

# !PYTHONPATH=".:./eomt" python main.py validate \
  -c configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --trainer.devices 1 \
  --data.batch_size 1 \
  --data.path "/content/drive/MyDrive/Cityscapes_Dataset_Zip" \
  --model.ckpt_path "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/eomt_cityscapes.bin"
# Out:
# /content/MaskArchitectureAnomaly_CourseProject/eomt
# 2026-06-26 09:03:01.990927: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Seed set to 0
# INFO:root:Loaded 197 keys
# Using 16bit Automatic Mixed Precision (AMP)
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
###### EOMT ######
# %cd /content/MaskArchitectureAnomaly_CourseProject/

# !PYTHONPATH=".:./eomt" python eval/evalAnomaly.py \
  --model_type eomt \
  --loadDir "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/" \
  --loadWeights "eomt_cityscapes.bin" \
  --input "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/datasets/Validation_Dataset/RoadAnomaly21/images/*.png"
# Out:
# /content/MaskArchitectureAnomaly_CourseProject
# Device: cuda
#
# START OF EVALUATION WITH MODEL: EOMT
#
#
# Weights path for EoMT: /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/eomt_cityscapes.bin
# Checkpoint EoMT correctly loaded (Strict=True)
#
# Anomaly dataset evaluation in progress...
# Found 10 anomaly images.
#
# ...
# Final metrics calculation
# ...
# [MSP] AUPRC: 74.37% | FPR95: 33.73%
# [MAX LOGIT] AUPRC: 73.99% | FPR95: 33.90%
# [ENTROPIA] AUPRC: 75.74% | FPR95: 33.60%
# [RBA] AUPRC: 76.45% | FPR95: 33.12%
#
# TEST TEMPERATURE SCALING FOR MSP (GRID SEARCH)
# Temp     | AUPRC (%)    | FPR95 (%)
# 0.1      | 74.77        | 52.90
# 0.2      | 74.21        | 52.90
# 0.5      | 73.64        | 53.37
# 0.8      | 73.27        | 47.20
# 0.8      | 72.95        | 47.26
# 1.0      | 73.85        | 33.66        (Standard)
# 1.1      | 74.30        | 29.93
# 1.2      | 74.65        | 27.46
# 1.5      | 75.36        | 23.22
# 2.0      | 79.15        | 11.57
# ...

# %%
### Fine-tuning EoMT - LogitNorm ###

import os
os.environ["WANDB_API_KEY"] = "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"

# %cd /content/MaskArchitectureAnomaly_CourseProject/eomt

# !PYTHONPATH=".:..:./eomt" python main.py fit \
  -c configs/dinov2/cityscapes/semantic/eomt_base_640.yaml \
  --trainer.devices 1 \
  --trainer.max_epochs 1 \
  --data.batch_size 2 \
  --data.path /content/drive/MyDrive/Cityscapes_Dataset_Zip \
  --model.ckpt_path /content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/eomt_cityscapes.bin \
  --model.loss_variant logitnorm \
  --model.logitnorm_tau 0.01 \
  --model.freeze_strategy queries_only \
  --trainer.accumulate_grad_batches 8
# Out:
# /content/MaskArchitectureAnomaly_CourseProject/eomt
# 2026-06-22 22:05:39.637844: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Seed set to 0
# INFO:root:Loaded 197 keys
# [freeze_strategy=queries_only] trainable params: 76,800 / 95,415,572 (0.08%)
# Using 16bit Automatic Mixed Precision (AMP)
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# ...

# %%
### Eval anomaly on checkpoint fine-tuned with logitnorm ###

# %cd /content/MaskArchitectureAnomaly_CourseProject/


# !PYTHONPATH=".:./eomt" python eval/evalAnomaly.py \
  --model_type eomt \
  --loadDir "/content/drive/MyDrive/Checkpoints_Estensione/" \
  --loadWeights "tau_0.01_none.ckpt" \
  --input "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/datasets/Validation_Dataset/RoadAnomaly/images/*.jpg"\
  --label "/content/drive/MyDrive/MaskArchitectureAnomaly_CourseProject/datasets/Validation_Dataset/RoadAnomaly/images/*.jpg"\
  --apply_norm
# Out:
# /content/MaskArchitectureAnomaly_CourseProject
# Device in uso: cuda
#
# INIZIO VALUTAZIONE CON MODELLO: EOMT
#
#
# Caricamento pesi EoMT da: /content/drive/MyDrive/Checkpoints_Estensione/tau_0.01_none.ckpt
# Rilevato checkpoint PyTorch Lightning (.ckpt). Estraggo i pesi...
# Checkpoint EoMT caricato correttamente (Strict=True)
#
# Lettura Dataset Anomalie
# Trovati 60 file anomalie.
#
# [*] Immagine di debug salvata: debug_pred_RoadAnomaly.png
#
# ...
# CALCOLO METRICHE FINALI
# ...
# [MSP] AUPRC: 75.49% | FPR95: 18.45%
# [MAX LOGIT] AUPRC: 74.91% | FPR95: 18.26%
# [ENTROPIA] AUPRC: 76.97% | FPR95: 17.99%
# [RBA] AUPRC: 78.06% | FPR95: 16.88%
#
# Report completo salvato in 'results.txt'
